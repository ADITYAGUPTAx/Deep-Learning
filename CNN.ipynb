# %% [markdown]
# <a href="https://colab.research.google.com/github/ADITYAGUPTAx/Deep-Learning/blob/main/CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import keras
import numpy as np
import pandas as pd

# %%
(x1,y1),(x2,y2)= keras.datasets.cifar10.load_data()
# Out:
# ...
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-951592244.py in <cell line: 0>()
# ----> 1 (x1,y1),(x2,y2)= keras.datasets.cifar10.load_data()
#
# /usr/local/lib/python3.12/dist-packages/keras/src/datasets/cifar10.py in load_data()
#      63     dirname = "cifar-10-batches-py-target"
#      64     origin = "https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz"
# ---> 65     path = get_file(
#      66         fname=dirname,
#      67         origin=origin,
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/file_utils.py in get_file(fname, origin, untar, md5_hash, file_hash, cache_subdir, hash_algorithm, extract, archive_format, cache_dir, force_download)
#     337             archive_format = "tar"
#     338
# --> 339         status = extract_archive(
# ...

# %%
plt.imshow(x1[8])

# %%
x1[0]

# %%
y1=y1.reshape(-1,)

# %%
y1

# %%
x1=x1/255

# %%
x2=x2/255
x2

# %%
32*32*3

# %%
nn= keras.Sequential([
    keras.layers.Flatten(input_shape=(32,32,3)),
    keras.layers.Dense(3000,activation='relu'),
    keras.layers.Dropout(0.3),
    keras.layers.Dense(1000,activation='relu'),
    keras.layers.Dropout(0.3),
    keras.layers.Dense(10,activation='sigmoid')
])

nn.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

nn.fit(x1,y1,epochs=10)

# %%
from tensorflow.keras import models,layers

# %%
from tensorflow.keras import models, layers, Input

cnn = models.Sequential([
    Input(shape=(32, 32, 3)),
    layers.Conv2D(filters=40, kernel_size=(3,3), activation='relu'),
    layers.MaxPooling2D(pool_size=(2,2)),
    layers.Conv2D(filters=60, kernel_size=(3,3), activation='relu'),
    layers.MaxPooling2D(pool_size=(2,2)),
    layers.Flatten(),
    layers.Dense(60, activation='relu'),
    layers.Dropout(0.3),
    layers.Dense(10, activation='softmax')
])

cnn.compile(optimizer='adam',
            loss='sparse_categorical_crossentropy',
            metrics=['accuracy'])

cnn.fit(x1, y1, epochs=10)

# %%
cnn.evaluate(x2,y2)

# %%
y_pred= cnn.predict(x2)

# %%
y_pred=[np.argmax(element) for element in y_pred]

# %%
y_pred[:5]

# %%
(x1, y1) , (x2, y2) = keras.datasets.mnist.load_data()

# %%
x1.shape

# %%
x1[0]

# %%
x1=x1/255
x2=x2/255

# %%
y1

# %%
CNN = models.Sequential([
    layers.Conv2D(filters=18,kernel_size=(3,3), input_shape=(28,28,1),activation='relu'),
    layers.AveragePooling2D(pool_size=(2,2)),
    layers.Conv2D(36,kernel_size=(3,3),activation='relu'),
    layers.AveragePooling2D(pool_size=(2,2)),
    layers.Flatten(),
    layers.Dense(128,activation='relu'),
    layers.Dropout(0.4),
    layers.Dense(10,activation='softmax')
])

CNN.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

CNN.fit(x1,y1,epochs=10)

# %%
CNN.evaluate(x2,y2)

# %%
y_pred=[np.argmax(i) for i in CNN.predict(x2)]

# %%
y_pred[:10]

# %%
from sklearn.metrics import confusion_matrix, classification_report
cn=confusion_matrix(y2,y_pred)
print(classification_report(y2,y_pred))

# %%
import seaborn as sns

sns.heatmap(cn, annot=True,fmt="2d")
plt.figure(figsize=(10,10))

# %% [markdown]
# Augmentation

# %%
import PIL
import os
import tensorflow as tf
from tensorflow import keras
import keras
from tensorflow.keras import layers
import cv2

# %%
dataset_url = "https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"
data_dir = tf.keras.utils.get_file('flower_photos', origin=dataset_url,  cache_dir='.', untar=True)

# %%
data_dir
# Out:
# './datasets/flower_photos'

# %%
import pathlib
data_dir=pathlib.Path(data_dir)
data_dir
# Out:
# PosixPath('datasets/flower_photos')

# %%
roses=list(data_dir.glob('*/roses/*'))

# %%
dandelion=list(data_dir.glob('*/dandelion/*'))

# %%
daisy=list(data_dir.glob('*/daisy/*'))

# %%
sunflowers=list(data_dir.glob('*/sunflowers/*'))

# %%
tulips=list(data_dir.glob('*/tulips/*'))

# %%
PIL.Image.open(roses[5])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x240>

# %%
dic={}
dic['roses']=roses
dic['dandelion']=dandelion
dic['daisy']=daisy
dic['sunflowers']=sunflowers
dic['tulips']=tulips

# %%
label_dic={
    "roses":0,
    "dandelion":1,
    "daisy":2,
    "sunflowers":3,
    "tulips":4
}

# %%
img=cv2.imread('datasets/flower_photos/flower_photos/tulips/8713398614_88202e452e_n.jpg')

# %%
img
# Out:
# array([[[ 1,  3,  3],
#         [ 0,  0,  0],
#         [ 3,  3,  3],
#         ...,
#         [16, 23, 16],
#         [15, 22, 19],
#         [ 1, 11, 11]],
#
#        [[ 4,  7,  5],
#         [ 2,  3,  1],
#         [ 3,  4,  2],
#         ...,
#         [63, 69, 64],
#         [67, 73, 72],
#         [56, 64, 64]],
#
#        [[ 5,  8,  6],
#         [ 3,  6,  4],
#         [ 2,  3,  1],
#         ...,
#         [86, 90, 85],
#         [84, 89, 88],
#         [76, 84, 84]],
#
#        ...,
#
#        [[27, 43, 25],
#         [64, 80, 49],
#         [52, 70, 31],
#         ...,
#         [36, 44, 21],
#         [30, 39, 18],
#         [32, 38, 21]],
#
#        [[34, 52, 29],
#         [69, 86, 52],
#         [52, 71, 28],
#         ...,
#         [34, 43, 22],
#         [29, 38, 17],
#         [31, 36, 21]],
#
#        [[41, 57, 33],
#         [68, 85, 48],
#         [55, 75, 30],
#         ...,
#         [34, 43, 22],
#         [30, 40, 17],
#         [33, 38, 23]]], dtype=uint8)

# %%
cv2.resize(img,(180,180))
# Out:
# array([[[ 1,  2,  2],
#         [ 3,  3,  3],
#         [ 1,  1,  1],
#         ...,
#         [13, 27, 15],
#         [21, 28, 21],
#         [11, 20, 19]],
#
#        [[ 3,  6,  4],
#         [ 3,  4,  2],
#         [ 3,  4,  2],
#         ...,
#         [34, 48, 36],
#         [65, 71, 65],
#         [65, 72, 72]],
#
#        [[ 5,  7,  6],
#         [ 2,  3,  1],
#         [ 5,  6,  4],
#         ...,
#         [48, 61, 49],
#         [83, 87, 81],
#         [76, 83, 83]],
#
#        ...,
#
#        [[36, 51, 31],
#         [51, 69, 34],
#         [15, 37, 23],
#         ...,
#         [44, 50, 24],
#         [37, 45, 20],
#         [32, 39, 19]],
#
#        [[46, 63, 37],
#         [50, 69, 29],
#         [18, 41, 25],
#         ...,
#         [44, 52, 22],
#         [35, 44, 21],
#         [30, 37, 19]],
#
#        [[51, 67, 39],
#         [52, 72, 29],
#         [19, 41, 22],
#         ...,
#         [44, 53, 21],
#         [34, 43, 21],
#         [32, 38, 21]]], dtype=uint8)

# %%
x,y=[],[]

for fn, im in dic.items():
  print(fn)
  for imgx in im:
    img=cv2.imread(str(imgx))
    rimg=cv2.resize(img,(180,180))
    x.append(rimg)
    y.append(label_dic[fn])
# Out:
# roses
# dandelion
# daisy
# sunflowers
# tulips

# %%
import numpy as np

x=np.array(x)
y=np.array(y)

x=x/255

# %%
from sklearn.model_selection import train_test_split
x1,x2,y1,y2=train_test_split(x,y)

# %%
from keras import Sequential

# %%
model= Sequential([
    layers.Conv2D(16,3,activation='relu',padding='same',input_shape=(180,180,3)),
    layers.MaxPooling2D(),
    layers.Conv2D(40,3,padding='same',activation='relu'),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dense(128,activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(20,activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(5,activation='softmax')
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

model.fit(x1,y1,epochs=20)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/20
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 84s 945ms/step - accuracy: 0.2340 - loss: 2.2902
# Epoch 2/20
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 136s 892ms/step - accuracy: 0.3762 - loss: 1.4749
# Epoch 3/20
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 76s 887ms/step - accuracy: 0.4376 - loss: 1.3738
# Epoch 4/20
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 81s 881ms/step - accuracy: 0.4977 - loss: 1.2609
# Epoch 5/20
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 77s 902ms/step - accuracy: 0.5519 - loss: 1.1235
# Epoch 6/20
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 80s 932ms/step - accuracy: 0.6086 - loss: 1.0065
# Epoch 7/20
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 77s 879ms/step - accuracy: 0.6341 - loss: 0.8945
# Epoch 8/20
# ...

# %%
keras.utils.plot_model(model, "my_first_model.png",show_shapes=True)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_2 (Conv2D)               │ (None, 180, 180, 16)   │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 90, 90, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 90, 90, 40)     │         5,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 45, 45, 40)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 81000)          │             0 │
# ...

# %%
pip show tensorflow
# Out:
# Name: tensorflow
# Version: 2.19.0
# Summary: TensorFlow is an open source machine learning framework for everyone.
# Home-page: https://www.tensorflow.org/
# Author: Google Inc.
# Author-email: packages@tensorflow.org
# License: Apache 2.0
# Location: /usr/local/lib/python3.12/dist-packages
# Requires: absl-py, astunparse, flatbuffers, gast, google-pasta, grpcio, h5py, keras, libclang, ml-dtypes, numpy, opt-einsum, packaging, protobuf, requests, setuptools, six, tensorboard, termcolor, typing-extensions, wrapt
# Required-by: dopamine_rl, tensorflow-text, tensorflow_decision_forests, tf_keras

# %%
pip install tf_keras==2.19.0

# %%
import tensorflow_hub as hub
import tf_keras
m = tf_keras.Sequential([
    hub.KerasLayer("https://www.kaggle.com/models/google/mobilenet-v2/TensorFlow2/035-128-classification/2")
])
m.build([None, 128, 128, 3])  # Batch input shape.

# %%
m.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  keras_layer_19 (KerasLayer  (None, 1001)              1692489
#  )
#
# ...
# Total params: 1692489 (6.46 MB)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1692489 (6.46 MB)
# _________________________________________________________________

# %%
a=PIL.Image.open('/content/GF.jpeg').resize((128,128))

# %%
a
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>

# %%
a1=np.array(a)/255.0

# %%
a1=a1[np.newaxis,]

# %%
a1.shape
# Out:
# (1, 128, 128, 3)

# %%
m.predict(a1)
# Out:
# 1/1 [==============================] - 0s 31ms/step
# array([[ 0.6998949,  4.8565702, 12.229227 , ..., -1.0458528,  1.2209145,
#         -0.4309072]], dtype=float32)

# %%
x1.shape
# Out:
# (2752, 180, 180, 3)

# %% [markdown]
# _

# %%
m2 = tf_keras.Sequential([
    hub.KerasLayer("https://www.kaggle.com/models/google/mobilenet-v2/TensorFlow2/035-128-classification/2",trainable=True)
])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3389461929.py in <cell line: 0>()
# ----> 1 m2 = tf_keras.Sequential([
#       2     hub.KerasLayer("https://www.kaggle.com/models/google/mobilenet-v2/TensorFlow2/035-128-classification/2",trainable=True)
#       3 ])
#
# NameError: name 'tf_keras' is not defined

# %%
import tensorflow_hub as hub
m2 = tf_keras.Sequential([
    hub.KerasLayer("https://www.kaggle.com/models/google/mobilenet-v2/TensorFlow2/035-128-feature-vector/2",
                   trainable=False),  # Can be True, see below.
    tf_keras.layers.Flatten(),
    tf_keras.layers.Dense(5, activation='softmax')
])
m2.build([None, 128, 128, 3])  # Batch input shape.

# %%
x1=np.resize(x1,(2752,128,128,3))

# %%
m2.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

m2.fit(x1,y1,epochs=5)
# Out:
# Epoch 1/5
# 86/86 [==============================] - 16s 131ms/step - loss: 1.6778 - accuracy: 0.2097
# Epoch 2/5
# 86/86 [==============================] - 12s 137ms/step - loss: 1.6186 - accuracy: 0.2420
# Epoch 3/5
# 86/86 [==============================] - 12s 137ms/step - loss: 1.5788 - accuracy: 0.2671
# Epoch 4/5
# 86/86 [==============================] - 12s 136ms/step - loss: 1.5504 - accuracy: 0.2845
# Epoch 5/5
# 86/86 [==============================] - 12s 138ms/step - loss: 1.5241 - accuracy: 0.3100
