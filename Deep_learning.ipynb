# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("blastchar/telco-customer-churn")

print("Path to dataset files:", path)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-4076359055.py in <cell line: 0>()
#       2
#       3 # Download latest version
# ----> 4 path = kagglehub.dataset_download("blastchar/telco-customer-churn")
#       5
#       6 print("Path to dataset files:", path)
#
# /usr/local/lib/python3.12/dist-packages/kagglehub/datasets.py in dataset_download(handle, path, force_download)
#      41     h = parse_dataset_handle(handle)
#      42     logger.info(f"Downloading Dataset: {h.to_url()} ...", extra={**EXTRA_CONSOLE_BLOCK})
# ---> 43     path, _ = registry.dataset_resolver(h, path, force_download=force_download)
#      44     return path
#      45
#
# /usr/local/lib/python3.12/dist-packages/kagglehub/registry.py in __call__(self, *args, **kwargs)
#      26         for impl in reversed(self._impls):
#      27             if impl.is_supported(*args, **kwargs):
# ...

# %%
import pandas as pd
import tensorflow as tf
import numpy as np

# %%
df=pd.read_csv("/kaggle/input/telco-customer-churn/WA_Fn-UseC_-Telco-Customer-Churn.csv")

# %%
df.head()

# %%
df.info()

# %%
df.describe()

# %%
train=df.drop(columns=['customerID','PaymentMethod','Churn'])

# %%
train

# %%
output=df['Churn']

# %%
a=pd.to_numeric(train.TotalCharges,errors='coerce')

# %%
train.TotalCharges=a

# %%
output

# %%
train.dropna(axis="rows",inplace=True)

# %%
train[train.TotalCharges.isnull()]

# %%
train

# %%
for col in train:
  print(col,train[col].unique())

# %%
# Identify columns with 'Yes' and 'No' values
yes_no_columns = ['Partner', 'Dependents', 'PhoneService', 'MultipleLines',
                  'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
                  'TechSupport', 'StreamingTV', 'StreamingMovies',
                  'PaperlessBilling']

for col in yes_no_columns:
    train[col] = train[col].replace({'Yes': 1, 'No': 0,'No internet service' : 0,'No phone service':0})

display(train)

# %%
train.gender.replace({'Female':0,'Male':1}, inplace=True)

# %%
train

# %%
train=pd.get_dummies(data=train,columns=['InternetService','Contract'],dtype=int)

# %%
from sklearn.preprocessing import MinMaxScaler as mms

scalar=mms()

# %%
cols=['tenure','MonthlyCharges','TotalCharges']

train[cols]=scalar.fit_transform(train[cols])

# %%
train

# %%
output_df=output.to_frame()
output_df['a']=a

# %%
output=output_df

# %%
output.dropna(axis='rows',inplace=True)

# %%
output.drop(columns='a',inplace=True)

# %%
output.Churn.replace({'Yes':1,'No':0},inplace=True)

# %%
from sklearn.model_selection import train_test_split as tts

x1,x2,y1,y2=tts(train,output)

# %%
y1

# %%
x1

# %%
from tensorflow import keras

# %%
model=keras.Sequential([
    keras.layers.Dense(22,input_shape=(22,),activation='relu'),
    keras.layers.Dense(11,activation='tanh'),
    keras.layers.Dropout(0.1),
    keras.layers.Dense(5,activation='relu'),
    keras.layers.Dense(1,activation='sigmoid')
])

model.compile(optimizer='adam', loss = 'binary_crossentropy', metrics=['Accuracy'])

model.fit(x1,y1,epochs=100)

# %%
model.evaluate(x2,y2)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model2=LogisticRegression()

model2.fit(x1,y1)

# %%
model2.score(x2,y2)

# %%
yp=model.predict(x2)

# %%
yp.shape

# %%
yp

# %%
y=[]

for i in yp:
  if i<0.5:
    y.append(0)
  else:
    y.append(1)

# %%
y[:5]

# %%
from sklearn.metrics import confusion_matrix as cm, classification_report as cs

# %%
print(cs(y,y2))

# %% [markdown]
# ##EXERCISE

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("barelydedicated/bank-customer-churn-modeling")

print("Path to dataset files:", path)

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import keras

# %%
df=pd.read_csv("/kaggle/input/bank-customer-churn-modeling/Churn_Modelling.csv")

# %%
df

# %%
df.info()

# %%
for col in df:
  print(df[col].unique())

# %%
input=df.drop(["RowNumber",'CustomerId','Surname','Exited'],axis='columns')

# %%
input2=pd.get_dummies(data=input,columns=["Geography"],dtype=int)

# %%
input2.replace({'Female':0,'Male':1},inplace=True)

# %%
input2

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()
input3=scaler.fit_transform(input2["Balance","EstimatedSalary","CreditScore","Age","Tenure","NumOfProducts"])

# %%
input4=pd.DataFrame(input3,columns=input2.columns)

# %%
output=df["Exited"]

# %%
from sklearn.model_selection import train_test_split as tts

x1,x2,y1,y2=tts(input4,output,test_size=0.2)

# %%
model=keras.Sequential([
    keras.layers.Dense(10,activation='relu'),
    keras.layers.Dense(5,activation='relu'),
    keras.layers.Dense(1,activation='sigmoid')
])

model.compile(optimizer='adam',loss='binary_crossentropy', metrics=['Accuracy'])

model.fit(x1,y1,epochs=100)

# %%
model.evaluate(x2,y2)

# %%
from sklearn.ensemble  import RandomForestClassifier as rfc

# %%
model2=rfc()

model2.fit(x1,y1)

# %%
model2.score(x2,y2)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model3=DecisionTreeClassifier()

model3.fit(x1,y1)

# %%
model3.score(x2,y2)

# %%
from sklearn.linear_model import LogisticRegression

model4=LogisticRegression()

model4.fit(x1,y1)

# %%
model4.score(x2,y2)

# %% [markdown]
# **DROPOUT**

# %%
df = pd.read_csv("sonar_dataset.csv")
df
# Out:
#      0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109  \
# 0    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 1    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 2    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 3    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# 4    0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  0.1201  0.1833  0.2105
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 202  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 203  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 204  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 205  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 206  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
# ...

# %%
df.describe()
# Out:
#            0.0200      0.0371      0.0428      0.0207      0.0954      0.0986  \
# count  207.000000  207.000000  207.000000  207.000000  207.000000  207.000000
# mean     0.029208    0.038443    0.043837    0.054053    0.075105    0.104599
# std      0.023038    0.033040    0.038521    0.046583    0.055669    0.059247
# min      0.001500    0.000600    0.001500    0.005800    0.006700    0.010200
# 25%      0.013300    0.016400    0.018900    0.024450    0.037700    0.066950
# 50%      0.022800    0.030800    0.034200    0.044100    0.062000    0.092100
# 75%      0.035800    0.048100    0.058200    0.065700    0.101050    0.134150
# max      0.137100    0.233900    0.305900    0.426400    0.401000    0.382300
#
#            0.1539      0.1601      0.3109      0.2111  ...      0.0232  \
# count  207.000000  207.000000  207.000000  207.000000  ...  207.000000
# mean     0.121591    0.134677    0.177361    0.208245  ...    0.016034
# ...

# %%
input=df.drop(["R"],axis='columns')
output=df["R"]

# %%
input
# Out:
#      0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109  \
# 0    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 1    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 2    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 3    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# 4    0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  0.1201  0.1833  0.2105
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 202  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 203  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 204  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 205  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 206  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
# ...

# %%
output=(output.replace({'M':0,'R':1}))
# Out:
# /tmp/ipython-input-1409633363.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   output=(output.replace({'M':0,'R':1}))

# %%
from sklearn.model_selection import train_test_split as tts

x1,x2,y1,y2=tts(input,output,test_size=0.2)

# %%
from tensorflow import keras

model=keras.Sequential([
    keras.layers.Dense(60,input_shape=(60,),activation='relu'),
    keras.layers.Dense(30,activation='relu'),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(1,activation='sigmoid')
])

model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['Accuracy'])

model.fit(x1,y1,epochs=150)
# Out:
# Epoch 1/150
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - Accuracy: 0.5088 - loss: 0.6957
# Epoch 2/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - Accuracy: 0.6285 - loss: 0.6572
# Epoch 3/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - Accuracy: 0.5846 - loss: 0.6579
# Epoch 4/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - Accuracy: 0.6258 - loss: 0.6476
# Epoch 5/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - Accuracy: 0.6048 - loss: 0.6441
# Epoch 6/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - Accuracy: 0.6268 - loss: 0.6445
# Epoch 7/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - Accuracy: 0.7045 - loss: 0.6151
# Epoch 8/150
# ...

# %%
model.evaluate(x2,y2)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - Accuracy: 0.8105 - loss: 0.4005
# [0.38811859488487244, 0.8095238208770752]

# %% [markdown]
# MODEL WITH JUST 0.2 DROPOUT GOT ONLY 80% ACCURACY ON TEST WHILE 98 ON TRAIN

# %%
from tensorflow import keras

model2=keras.Sequential([
    keras.layers.Dense(60,input_shape=(60,),activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(30,activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(10,activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(1,activation='sigmoid')
])

model2.compile(optimizer='adam',loss='binary_crossentropy',metrics=['Accuracy'])

model2.fit(x1,y1,epochs=500)
# Out:
# Epoch 1/500
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - Accuracy: 0.5436 - loss: 0.8024
# Epoch 2/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - Accuracy: 0.5150 - loss: 0.8305
# Epoch 3/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - Accuracy: 0.5464 - loss: 0.7257
# Epoch 4/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - Accuracy: 0.5245 - loss: 0.7319
# Epoch 5/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - Accuracy: 0.5338 - loss: 0.6819
# Epoch 6/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - Accuracy: 0.4843 - loss: 0.6969
# Epoch 7/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - Accuracy: 0.5445 - loss: 0.7064
# Epoch 8/500
# ...

# %%
model2.evaluate(x2,y2)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - Accuracy: 0.7897 - loss: 0.6598
# [0.613029420375824, 0.8095238208770752]
